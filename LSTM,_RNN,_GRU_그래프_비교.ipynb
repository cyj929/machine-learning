# %% [markdown]
# 21099.635
# 52889.45221

# %%
import numpy as np
y_predict = np.array([[0.69899786],
 [0.72422886],
 [0.7631487 ],
 [0.9298353 ],
 [0.9147129 ],
 [0.7285106 ],
 [0.753743  ],
 [0.7805297 ],
 [0.9667583 ],
 [0.9973455 ],
 [0.793773  ],
 [0.75671655]])

y_original = y_predict * (52889.45221 - 21099.635) + 21099.635

# %%
y_original 
#lstm
# Out:
# array([[43320.64919958],
#        [44122.73807761],
#        [45359.99267705],
#        [50658.92922241],
#        [50178.19089063],
#        [44258.85380955],
#        [45060.98719332],
#        [45912.53148998],
#        [51832.70464325],
#        [52805.06614022],
#        [46333.53357623],
#        [45155.51580428]])

# %%
import numpy as np[43320.64919958],
       [44122.73807761],
       [45359.99267705],
       [50658.92922241],
       [50178.19089063],
       [44258.85380955],
       [45060.98719332],
       [45912.53148998],
       [51832.70464325],
       [52805.06614022],
       [46333.53357623],
       [45155.51580428]])

y_predict = np.array([[0.71867496],
                     [0.7287134],
                     [0.75930804],
                     [0.87567776],
                     [0.86919796],
                     [0.73802537],
                     [0.6890609],
                     [0.82778704],
                     [0.9639036],
                     [0.97628886],
                     [0.8934365],
                     [0.76702195]])

y_original2 = y_predict * (52889.45221 - 21099.635) + 21099.635

# %%
y_original2
#gru
# Out:
# array([[43946.1806118 ],
#        [44265.30078448],
#        [45237.89879768],
#        [48937.27092526],
#        [48731.2792677 ],
#        [44561.32660864],
#        [43004.75505756],
#        [47414.83369041],
#        [51741.95425206],
#        [52135.67940356],
#        [49501.81802374],
#        [45483.12258656]])

# %%
import numpy as np

data = [
    [44787.812],
    [47323.04],
    [50728.5],
    [51103.016],
    [45243.76],
    [45726.69],
    [47069.316],
    [51050.85],
    [50461.8],
    [49677.996],
    [45520.043],
    [44944.87]
]

y_original3 = np.array(data)
print(y_original3)
#rnn
# Out:
# [[44787.812]
#  [47323.04 ]
#  [50728.5  ]
#  [51103.016]
#  [45243.76 ]
#  [45726.69 ]
#  [47069.316]
#  [51050.85 ]
#  [50461.8  ]
#  [49677.996]
#  [45520.043]
#  [44944.87 ]]

# %%
real_data = [
 [44340.78814],
 [45453.43341],
 [52643.66332],
 [51461.29845],
 [44230.74019],
 [43753.94057],
 [44338.6556 ],
 [52889.45221],
 [51651.5616 ],
 [45739.50828],
 [44077.47262],
 [40525.50384]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(y_original, color = 'red', label='LSTM')
plt.plot(real_data, color = 'blue', label='Real')
plt.plot(y_original2, color = 'green', label='GRU')
plt.plot(y_original3, color = 'yellow', label='RNN')
plt.ylabel('value')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %%
[[0.69899786]
 [0.72422886]
 [0.7631487 ]
 [0.9298353 ]
 [0.9147129 ]
 [0.7285106 ]
 [0.753743  ]
 [0.7805297 ]
 [0.9667583 ]
 [0.9973455 ]
 [0.793773  ]
 [0.75671655]]

# %%
import numpy as np
y_predict = np.array([[0.69899786],
 [0.72422886],
 [0.7631487 ],
 [0.9298353 ],
 [0.9147129 ],
 [0.7285106 ],
 [0.753743  ],
 [0.7805297 ],
 [0.9667583 ],
 [0.9973455 ],
 [0.793773  ],
 [0.75671655]])

y_original = y_predict * (52889.45221 - 21099.635) + 21099.635
y_original
# Out:
# array([[43320.64919958],
#        [44122.73807761],
#        [45359.99267705],
#        [50658.92922241],
#        [50178.19089063],
#        [44258.85380955],
#        [45060.98719332],
#        [45912.53148998],
#        [51832.70464325],
#        [52805.06614022],
#        [46333.53357623],
#        [45155.51580428]])
